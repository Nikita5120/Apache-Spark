# %%
pip install pyspark
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv(r"C:\Users\91705\Downloads\soil_nutrient_dataset.csv")
# Out:
#       image_name  nitrogen  phosphorus  potassium nutrient_level  \
# 0     soil_1.jpg      3.51        5.55       2.21         Medium
# 1     soil_2.jpg      5.26        1.64       7.74         Medium
# 2     soil_3.jpg      7.21        8.97       3.94           High
# 3     soil_4.jpg      7.93        3.36       8.64           High
# 4     soil_5.jpg      4.22        5.15       2.85         Medium
# ..           ...       ...         ...        ...            ...
# 95   soil_96.jpg      4.29        7.81       7.18           High
# 96   soil_97.jpg      8.69        1.76       6.12         Medium
# 97   soil_98.jpg      3.03        2.75       3.73         Medium
# 98   soil_99.jpg      6.72        4.26       8.65           High
# 99  soil_100.jpg      3.50        4.87       2.76         Medium
#
#                      recommendation
# 0   Balanced fertilization required
# 1   Balanced fertilization required
# 2         Minimal fertilizer needed
# 3         Minimal fertilizer needed
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Nikita:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv(r"C:\Users\91705\Downloads\soil_nutrient_dataset.csv")

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string]

# %%
df_pyspark.show
# Out:
# <bound method DataFrame.show of DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string]>

# %%
spark.read.option('header','true').csv(r"C:\Users\91705\Downloads\soil_nutrient_dataset.csv")
# Out:
# DataFrame[image_name: string, nitrogen: string, phosphorus: string, potassium: string, nutrient_level: string, recommendation: string]

# %%
spark.read.option('header','true').csv(r"C:\Users\91705\Downloads\soil_nutrient_dataset.csv").show()
# Out:
# +-----------+--------+----------+---------+--------------+--------------------+
# | image_name|nitrogen|phosphorus|potassium|nutrient_level|      recommendation|
# +-----------+--------+----------+---------+--------------+--------------------+
# | soil_1.jpg|    3.51|      5.55|     2.21|        Medium|Balanced fertiliz...|
# | soil_2.jpg|    5.26|      1.64|     7.74|        Medium|Balanced fertiliz...|
# | soil_3.jpg|    7.21|      8.97|     3.94|          High|Minimal fertilize...|
# | soil_4.jpg|    7.93|      3.36|     8.64|          High|Minimal fertilize...|
# | soil_5.jpg|    4.22|      5.15|     2.85|        Medium|Balanced fertiliz...|
# | soil_6.jpg|    8.26|      1.39|     4.62|        Medium|Balanced fertiliz...|
# | soil_7.jpg|    7.96|      2.08|      8.0|          High|Minimal fertilize...|
# | soil_8.jpg|     5.7|      3.15|     4.08|        Medium|Balanced fertiliz...|
# | soil_9.jpg|    8.84|      7.79|     5.68|          High|Minimal fertilize...|
# ...

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
